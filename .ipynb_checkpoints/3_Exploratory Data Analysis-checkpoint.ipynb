# %%
import numpy as np
import pandas as pd
import math
import sklearn
import sklearn.preprocessing
import datetime
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns 
sns.set()
# %matplotlib inline
from collections import Counter
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import seaborn as sns
sns.set()
pd.options.mode.chained_assignment = None  # default='warn'

from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Read in the cleansed and winsorised data
df = pd.read_csv('ger_factor_data_from2003.csv')
# #Convert to float 32 (format needed for the most ML models)
# df[df.columns[2:]] = df[df.columns[2:]].astype('float32')
# #Sort observations by date and stock id
# df = df.sort_values(by = ['eom', 'id'], ascending = True)
df.head()
# Out:
#       id         eom   ret_1_0   ret_6_1  ret_12_1     chmom  rmax1_21d  \
# 0  10026  2019-01-01  0.052962  0.004556 -0.032149 -0.085111   0.120143
# 1  10028  2019-01-01  0.095500 -0.416806 -0.562603 -0.658103   0.111363
# 2  10032  2019-01-01  0.105578 -0.152459 -0.170934 -0.276512   0.037847
# 3  10044  2019-01-01 -0.027906 -0.211287 -0.273494 -0.245588   0.028708
# 4  10051  2019-01-01  0.073959 -0.134729 -0.151793 -0.243987   0.032471
#
#    rvol_21d  turnover_126d  std_turn  ...            me  beta_60m    betasq  \
# 0  0.031862       3.762866  1.897606  ...  2.899156e+06  0.508698  0.258773
# 1  0.050379       1.821581  3.822366  ...  1.137001e+04 -0.202612  0.041051
# 2  0.019321       5.863347  3.705468  ...  1.734894e+06  0.932149  0.868901
# 3  0.019264       2.254771  1.831654  ...  5.116140e+04  0.096625  0.009336
# 4  0.019130       7.384375  9.936024  ...  7.730710e+05  0.782874  0.632728
#
#    ivol_capm_252d  year  month  sic2  ret_exc_lead1m       ret   ret_exc
# 0        0.014725  2019      1    20        0.090999  0.052962  0.052962
# 1        0.041514  2019      1    50       -0.114284  0.095500  0.095500
# 2        0.013816  2019      1    36        0.149659  0.105578  0.105578
# 3        0.013956  2019      1    20        0.099511 -0.027906 -0.027906
# 4        0.015394  2019      1    80       -0.014634  0.073959  0.073959
#
# [5 rows x 23 columns]

# %%
# The observation period contains 71 months in the period from 01.2019 to 11.2024', following up the period of 
# data selected in the original research paper (01.2003 to 01.2019)

# The last 11 months are not used since we use the last 11 months for testing (01.2024 to 11.2024)

df_2 = df[~(df['eom'] > '2023-12-31')]
print("Number of months: ", df_2["eom"].nunique())
print("Start: ", df_2["eom"].min())
print("End: ", df_2["eom"].max())
# Out:
# Number of months:  60
# Start:  2019-01-01
# End:  2023-12-01

# %%
#There are 1855 unique german stocks
print("Number of unique stcocks: ", df_2["id"].nunique())
# Out:
# Number of unique stcocks:  12219

# %%
#Inspect variable types
df_2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501990 entries, 0 to 501989
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                501990 non-null  int64
#  1   eom               501990 non-null  object
#  2   ret_1_0           501990 non-null  float64
#  3   ret_6_1           501990 non-null  float64
#  4   ret_12_1          501990 non-null  float64
#  5   chmom             501990 non-null  float64
#  6   rmax1_21d         501990 non-null  float64
#  7   rvol_21d          501990 non-null  float64
#  8   turnover_126d     501990 non-null  float64
#  9   std_turn          501990 non-null  float64
#  10  dolvol_126d       501990 non-null  float64
#  11  zero_trades_252d  501990 non-null  float64
#  12  bidaskhl_21d      501990 non-null  float64
#  13  me                501990 non-null  float64
#  14  beta_60m          501990 non-null  float64
#  15  betasq            501990 non-null  float64
#  16  ivol_capm_252d    501990 non-null  float64
#  17  year              501990 non-null  int64
#  18  month             501990 non-null  int64
#  19  sic2              501990 non-null  int64
#  20  ret_exc_lead1m    501990 non-null  float64
#  21  ret               501990 non-null  float64
#  22  ret_exc           501990 non-null  float64
# dtypes: float64(18), int64(4), object(1)
# memory usage: 91.9+ MB

# %%
#Number of stocks at each month; 
Number_stocks_per_month = Counter(df_2['eom'])
Number_stocks_per_month= pd.DataFrame(Number_stocks_per_month.items(), columns=['Date', 'Numer_of_Stocks'])
print("Minimum number of stocks pre month: ", Number_stocks_per_month["Numer_of_Stocks"].min())
print("Maximum number of stocks pre month: ", Number_stocks_per_month["Numer_of_Stocks"].max())
print("Mean number of stocks pre month: ", Number_stocks_per_month["Numer_of_Stocks"].mean())
Number_stocks_per_month.plot(x='Date', y='Numer_of_Stocks',grid=True,figsize=(15, 7));
# Out:
# Minimum number of stocks pre month:  7256
# Maximum number of stocks pre month:  9312
# Mean number of stocks pre month:  8366.5

# %% [markdown]
# ### Descriptive Statistics of the characteristics

# %%
#We are interested in the descriptive statistics of all 49 stock level characteristics and the target variable (ret_exc_lead1m)
features = df.columns[~df.columns.isin(['id',"prc","eom","ret","ret_exc"])].tolist()

# %%
descriptive_statistics = df_2[features].describe()
descriptive_statistics
# Out:
#              ret_1_0        ret_6_1       ret_12_1          chmom  \
# count  501990.000000  501990.000000  501990.000000  501990.000000
# mean        0.005574       0.012114       0.032441       0.026507
# std         0.140260       0.362464       0.461398       0.476093
# min        -0.417953      -0.815192      -0.889320      -1.099408
# 25%        -0.052329      -0.155119      -0.183036      -0.199507
# 50%         0.004169       0.000188       0.000694       0.000862
# 75%         0.057255       0.138344       0.179183       0.191019
# max         0.561937       1.584860       2.144149       2.152889
#
#            rmax1_21d       rvol_21d  turnover_126d       std_turn  \
# count  501990.000000  501990.000000  501990.000000  501990.000000
# mean        0.057602       0.026297      16.900862      31.060920
# std         0.065079       0.024008      40.162231     108.641033
# min         0.001623       0.000813       0.425897       0.505227
# 25%         0.018760       0.010190       3.705795       2.897162
# 50%         0.036649       0.018994       6.765783       5.969811
# 75%         0.070961       0.034775      12.496703      14.556657
# max         0.404651       0.135545     321.717655     927.429595
#
#         dolvol_126d  zero_trades_252d   bidaskhl_21d            me  \
# count  5.019900e+05     501990.000000  501990.000000  5.019900e+05
# mean   3.914812e+07          0.008814       0.005444  4.380140e+06
# std    1.166413e+08          0.040601       0.009207  1.368697e+07
# min    1.135875e+04          0.000000       0.000144  2.213000e+03
# 25%    4.783465e+05          0.000000       0.000760  7.838410e+04
# 50%    2.736942e+06          0.000000       0.001887  3.655847e+05
# 75%    1.858591e+07          0.000000       0.005057  1.995669e+06
# max    8.299437e+08          0.289683       0.053164  1.020918e+08
#
#             beta_60m         betasq  ivol_capm_252d           year  \
# count  501990.000000  501990.000000   501990.000000  501990.000000
# mean        0.915272       1.183641        0.024792    2021.125975
# std         0.553413       1.312186        0.021731       1.400749
# min        -0.679951       0.000039        0.001216    2019.000000
# 25%         0.607901       0.392746        0.009980    2020.000000
# 50%         0.904457       0.841194        0.017967    2021.000000
# 75%         1.195967       1.459265        0.032610    2022.000000
# max         2.741696       8.212564        0.120809    2023.000000
#
#                month           sic2  ret_exc_lead1m
# count  501990.000000  501990.000000   501990.000000
# mean        6.543441      65.525481        0.003320
# std         3.454233      23.134554        0.140534
# min         1.000000       0.000000       -0.425032
# 25%         4.000000      59.000000       -0.054008
# 50%         7.000000      67.000000        0.003366
# 75%        10.000000      73.000000        0.054733
# max        12.000000      99.000000        0.563692

# %%
#descriptive_statistics.to_excel(r'C:\Users\krist\Documents\Data\EDA\descriptive_statistics.xlsx')

# %% [markdown]
# ### Distribution of each feature

# %%
fig, ax = plt.subplots()
fig.set_figheight(30)
fig.set_figwidth(30)
df[features].hist(layout=(-1, 3), bins=np.linspace(-1,1,50), ax=ax);

# %% [markdown]
# ### Distribution of portfolio returns

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
df_3 = df_2[["ret"]]
df_3 = df_3.rename(columns={'ret': 'Stock return'})
sns.histplot(data = df_3, x ="Stock return", binwidth = 0.01, binrange = (df_3["Stock return"].min()+ 0.00000000001, df_3["Stock return"].max()- 0.01))
plt.savefig('returns_distrubution.png')

# %% [markdown]
# ### Distribution of firm size

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 10
sns.histplot(data = df_2, x ="me", binrange = (0,15000))
plt.savefig('size_distrubution.png')

# %% [markdown]
# ### Equally weighted portfolio monthly returns over time

# %%
#retain only return data over time
ret_data = df_2[["ret", "id", "eom"]]
#create equal weights
ret_data["eq_weights"] = 1/ret_data.groupby('eom')["id"].transform('size')
#calculate montly return of the equally weighted portfolio contaning all stocks
ret_data['return_stock_ew'] = ret_data["ret"]*ret_data["eq_weights"]
ret_data['Returns'] = ret_data.groupby('eom')["return_stock_ew"].transform('sum')
#drop duplicates 
ret_data = ret_data[["eom", "Returns"]].drop_duplicates()
#rename eon (end of month) to "date"
ret_data = ret_data.rename(columns={'eom': 'Date'})
ret_data = ret_data.set_index("Date")
#plot the portfolio returns over time
ret_data.plot(grid=True,figsize=(15, 7));
#save grapgh
plt.savefig('portfolio monthly returns over time.png')

# %% [markdown]
# ### Portfolio autocorrelation graph

# %%
plot_acf(ret_data)
# Show the data as a plot (via matplotlib)
plt.show()
plt.savefig('Portfolio autocorrelation graph.png')

# %% [markdown]
# ## Variable Correlation Heatmap

# %%
features = df.columns[~df.columns.isin(['id',"prc","eom","ret","ret_exc"])].tolist()
plt.figure(figsize = (18,18))
sns.heatmap(data=df_2[features].corr())
plt.title('Correlation Heatmap')
plt.savefig('Correlation Heatmap.png')
plt.show()
plt.gcf().clear()

# %% [markdown]
# ## Top Correlated Features (Pearson’s correlation)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
c = df_2[features].corr().abs()
s = c.unstack()
so = s.sort_values(kind="quicksort").reset_index()
so.columns = ['Variable 1','Variable 2', 'corr']
so = so.sort_values(by = ['corr', 'Variable 1'], ascending = False)
so = so[so['corr']!=1]
so = so.iloc[::2].reset_index(drop=True)
so
# Out:
#            Variable 1      Variable 2      corr
# 0            ret_12_1           chmom  0.957494
# 1            rvol_21d       rmax1_21d  0.917116
# 2                  me     dolvol_126d  0.813184
# 3       turnover_126d        std_turn  0.805406
# 4              betasq        beta_60m  0.785807
# 5             ret_6_1        ret_12_1  0.767594
# 6             ret_6_1           chmom  0.725515
# 7            rvol_21d  ivol_capm_252d  0.678469
# 8           rmax1_21d  ivol_capm_252d  0.617385
# 9            std_turn  ivol_capm_252d  0.398834
# 10     ivol_capm_252d    bidaskhl_21d  0.391477
# 11           rvol_21d    bidaskhl_21d  0.376702
# 12     ivol_capm_252d          betasq  0.355602
# 13      turnover_126d  ivol_capm_252d  0.343312
# 14          rmax1_21d    bidaskhl_21d  0.342242
# 15           rvol_21d          betasq  0.335725
# 16     ivol_capm_252d        beta_60m  0.333872
# 17           rvol_21d        beta_60m  0.320781
# 18           std_turn        rvol_21d  0.291148
# 19           std_turn       rmax1_21d  0.287750
# 20      turnover_126d        rvol_21d  0.277384
# 21          rmax1_21d          betasq  0.270619
# 22      turnover_126d          betasq  0.263911
# 23          rmax1_21d        beta_60m  0.258704
# 24            ret_1_0           chmom  0.257569
# 25      turnover_126d       rmax1_21d  0.255293
# 26          rmax1_21d           chmom  0.214611
# 27           ret_12_1    bidaskhl_21d  0.200179
# 28          rmax1_21d         ret_1_0  0.198936
# 29            ret_6_1    bidaskhl_21d  0.185271
# 30           rvol_21d        ret_12_1  0.177406
# 31        dolvol_126d    bidaskhl_21d  0.176709
# 32              chmom    bidaskhl_21d  0.173957
# 33           rvol_21d         ret_6_1  0.173836
# 34          rmax1_21d        ret_12_1  0.170847
# 35                 me    bidaskhl_21d  0.169199
# 36           rvol_21d           chmom  0.165074
# 37          rmax1_21d         ret_6_1  0.161044
# 38               sic2    bidaskhl_21d  0.154173
# 39               sic2              me  0.144740
# 40   zero_trades_252d        beta_60m  0.144594
# 41           std_turn    bidaskhl_21d  0.144559
# 42      turnover_126d     dolvol_126d  0.130045
# 43   zero_trades_252d        rvol_21d  0.124715
# 44                 me  ivol_capm_252d  0.124094
# 45       bidaskhl_21d        beta_60m  0.119055
# 46   zero_trades_252d  ivol_capm_252d  0.112899
# 47   zero_trades_252d          betasq  0.111161
# 48               sic2     dolvol_126d  0.110810
# 49        dolvol_126d          betasq  0.103070
# 50       bidaskhl_21d          betasq  0.101971
# 51   zero_trades_252d       rmax1_21d  0.099894
# 52               sic2        rvol_21d  0.098753
# 53               sic2  ivol_capm_252d  0.095998
# 54           rvol_21d              me  0.094705
# 55           ret_12_1  ivol_capm_252d  0.093400
# 56           ret_12_1     dolvol_126d  0.091543
# 57           std_turn          betasq  0.090767
# 58           ret_12_1              me  0.088515
# 59        dolvol_126d        beta_60m  0.087846
# 60               sic2       rmax1_21d  0.087514
# 61               year            sic2  0.086465
# 62           std_turn            sic2  0.084823
# 63        dolvol_126d           chmom  0.084266
# 64          rmax1_21d              me  0.084086
# 65     ivol_capm_252d           chmom  0.082495
# 66               sic2        ret_12_1  0.080539
# 67               sic2         ret_6_1  0.077908
# 68                 me           chmom  0.077029
# 69            ret_6_1              me  0.076023
# 70     ret_exc_lead1m           month  0.073434
# 71           std_turn              me  0.072954
# 72   zero_trades_252d     dolvol_126d  0.071696
# 73            ret_6_1     dolvol_126d  0.071450
# 74            ret_1_0    bidaskhl_21d  0.070868
# 75     ivol_capm_252d     dolvol_126d  0.069205
# 76               year         ret_6_1  0.068261
# 77            ret_6_1  ivol_capm_252d  0.068240
# 78   zero_trades_252d    bidaskhl_21d  0.068031
# 79   zero_trades_252d              me  0.067605
# 80               sic2           chmom  0.066384
# 81            ret_6_1          betasq  0.065900
# 82               year        ret_12_1  0.062814
# 83           std_turn  ret_exc_lead1m  0.060731
# 84               year         ret_1_0  0.059356
# 85           rvol_21d           month  0.059301
# 86           std_turn        ret_12_1  0.056815
# 87   zero_trades_252d            sic2  0.053910
# 88               year    bidaskhl_21d  0.053853
# 89               year  ret_exc_lead1m  0.053582
# 90      turnover_126d              me  0.052999
# 91      turnover_126d  ret_exc_lead1m  0.050795
# 92      turnover_126d            sic2  0.049394
# 93           std_turn           chmom  0.048715
# 94               sic2         ret_1_0  0.047617
# 95               sic2  ret_exc_lead1m  0.046138
# 96   zero_trades_252d   turnover_126d  0.045778
# 97               year           chmom  0.043668
# 98           std_turn         ret_6_1  0.042438
# 99           ret_12_1          betasq  0.041872
# 100    ret_exc_lead1m         ret_6_1  0.039650
# 101         rmax1_21d     dolvol_126d  0.037134
# 102         rmax1_21d           month  0.036951
# 103                me        beta_60m  0.036064
# 104           ret_6_1        beta_60m  0.035240
# 105           ret_6_1         ret_1_0  0.034297
# 106          rvol_21d     dolvol_126d  0.034160
# 107    ret_exc_lead1m  ivol_capm_252d  0.033773
# 108             chmom          betasq  0.033694
# 109     turnover_126d        ret_12_1  0.033397
# 110    ret_exc_lead1m    bidaskhl_21d  0.033248
# 111     turnover_126d        beta_60m  0.032889
# 112           ret_1_0              me  0.030928
# 113           ret_1_0           month  0.030746
# 114    ret_exc_lead1m         ret_1_0  0.029874
# 115          std_turn         ret_1_0  0.028605
# 116     turnover_126d         ret_1_0  0.028037
# 117              year          betasq  0.027325
# 118              year        std_turn  0.026485
# 119     turnover_126d         ret_6_1  0.025953
# 120     turnover_126d           chmom  0.025690
# 121              year        beta_60m  0.023860
# 122     turnover_126d    bidaskhl_21d  0.023463
# 123           ret_6_1           month  0.021618
# 124             month          betasq  0.021040
# 125             month        beta_60m  0.019497
# 126    ret_exc_lead1m          betasq  0.019315
# 127           ret_1_0  ivol_capm_252d  0.015487
# 128    ret_exc_lead1m              me  0.015388
# 129             month           chmom  0.015280
# 130           ret_1_0     dolvol_126d  0.014853
# 131          ret_12_1        beta_60m  0.014484
# 132    ret_exc_lead1m        ret_12_1  0.014049
# 133          std_turn     dolvol_126d  0.014022
# 134              sic2          betasq  0.013723
# 135           ret_1_0          betasq  0.013635
# 136             chmom        beta_60m  0.013237
# 137              sic2           month  0.012666
# 138              year  ivol_capm_252d  0.012594
# 139    ret_exc_lead1m     dolvol_126d  0.012489
# 140             month  ivol_capm_252d  0.009985
# 141  zero_trades_252d        ret_12_1  0.009364
# 142              year        rvol_21d  0.009214
# 143  zero_trades_252d           chmom  0.008974
# 144              sic2        beta_60m  0.008559
# 145              year   turnover_126d  0.008377
# 146          rvol_21d  ret_exc_lead1m  0.008300
# 147             month    bidaskhl_21d  0.007484
# 148             month     dolvol_126d  0.007419
# 149           ret_1_0        ret_12_1  0.006645
# 150    ret_exc_lead1m           chmom  0.006504
# 151          std_turn           month  0.006038
# 152  zero_trades_252d           month  0.005581
# 153          ret_12_1           month  0.005530
# 154                me          betasq  0.005407
# 155           ret_1_0        beta_60m  0.005044
# 156  zero_trades_252d            year  0.004490
# 157    ret_exc_lead1m        beta_60m  0.004135
# 158              year           month  0.004053
# 159          std_turn        beta_60m  0.003535
# 160          rvol_21d         ret_1_0  0.002889
# 161              year     dolvol_126d  0.002750
# 162  zero_trades_252d        std_turn  0.002266
# 163     turnover_126d           month  0.002261
# 164  zero_trades_252d  ret_exc_lead1m  0.002015
# 165  zero_trades_252d         ret_1_0  0.001821
# 166         rmax1_21d  ret_exc_lead1m  0.001797
# 167             month              me  0.001696
# 168              year       rmax1_21d  0.001190
# 169              year              me  0.000501
# 170  zero_trades_252d         ret_6_1  0.000060

# %%
#so.to_excel(r'C:\Users\krist\Documents\Data\EDA\variable_correlation.xlsx')

# %% [markdown]
# ## Correlation of the stock level characteristics with the target variable (ret_exc_lead1m)

# %%
# 1. Check the data types of all columns
print("df_2 data types of all columns：")
print(df_2.dtypes)

# 2. Filter out numeric columns (int64, float64 types) and exclude non-numeric columns
numeric_cols = df_2.select_dtypes(include=['int64', 'float64']).columns
df_numeric = df_2[numeric_cols]

# 3. Check if the target column 'ret_exc_lead1m' is among the numeric columns
if 'ret_exc_lead1m' not in numeric_cols:
    print(f"Warning：'ret_exc_lead1m' It is not a numeric column; please handle the format of this column first.")
else:
    # 4. Compute Correlation
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    correlation = df_numeric.corr()["ret_exc_lead1m"].abs().sort_values(ascending=False)
    corr_df = pd.DataFrame(correlation)
    print("\n Corrlation Result：")
    print(corr_df)
# Out:
# df_2 data types of all columns：
# id                    int64
# ret_1_0             float64
# ret_6_1             float64
# ret_12_1            float64
# chmom               float64
# rmax1_21d           float64
# rvol_21d            float64
# turnover_126d       float64
# std_turn            float64
# dolvol_126d         float64
# zero_trades_252d    float64
# bidaskhl_21d        float64
# me                  float64
# beta_60m            float64
# betasq              float64
# ivol_capm_252d      float64
# year                  int32
# month                 int32
# sic2                  int64
# ret_exc_lead1m      float64
# ret                 float64
# ret_exc             float64
# dtype: object
#
#  Corrlation Result：
#                   ret_exc_lead1m
# ret_exc_lead1m          1.000000
# std_turn                0.060731
# turnover_126d           0.050795
# sic2                    0.046138
# ret_6_1                 0.039650
# ivol_capm_252d          0.033773
# bidaskhl_21d            0.033248
# id                      0.030248
# ret                     0.029874
# ret_exc                 0.029874
# ret_1_0                 0.029874
# betasq                  0.019315
# me                      0.015388
# ret_12_1                0.014049
# dolvol_126d             0.012489
# rvol_21d                0.008300
# chmom                   0.006504
# beta_60m                0.004135
# zero_trades_252d        0.002015
# rmax1_21d               0.001797

# %%
if 'eom' in df_2.columns:
    df_2['eom'] = pd.to_datetime(df_2['eom'])
    
    df_2['year'] = df_2['eom'].dt.year  
    df_2['month'] = df_2['eom'].dt.month 
    
    df_2 = df_2.drop('eom', axis=1)

# %%
df_2.head()
# Out:
#       id   ret_1_0   ret_6_1  ret_12_1     chmom  rmax1_21d  rvol_21d  \
# 0  10026  0.052962  0.004556 -0.032149 -0.085111   0.120143  0.031862
# 1  10028  0.095500 -0.416806 -0.562603 -0.658103   0.111363  0.050379
# 2  10032  0.105578 -0.152459 -0.170934 -0.276512   0.037847  0.019321
# 3  10044 -0.027906 -0.211287 -0.273494 -0.245588   0.028708  0.019264
# 4  10051  0.073959 -0.134729 -0.151793 -0.243987   0.032471  0.019130
#
#    turnover_126d  std_turn   dolvol_126d  zero_trades_252d  bidaskhl_21d  \
# 0       3.762866  1.897606  1.050593e+07          0.000000      0.001979
# 1       1.821581  3.822366  2.593482e+04          0.003968      0.026279
# 2       5.863347  3.705468  1.047941e+07          0.000000      0.000677
# 3       2.254771  1.831654  1.203997e+05          0.000000      0.018830
# 4       7.384375  9.936024  5.403155e+06          0.000000      0.001205
#
#              me  beta_60m    betasq  ivol_capm_252d  year  month  sic2  \
# 0  2.899156e+06  0.508698  0.258773        0.014725  2019      1    20
# 1  1.137001e+04 -0.202612  0.041051        0.041514  2019      1    50
# 2  1.734894e+06  0.932149  0.868901        0.013816  2019      1    36
# 3  5.116140e+04  0.096625  0.009336        0.013956  2019      1    20
# 4  7.730710e+05  0.782874  0.632728        0.015394  2019      1    80
#
#    ret_exc_lead1m       ret   ret_exc
# 0        0.090999  0.052962  0.052962
# 1       -0.114284  0.095500  0.095500
# 2        0.149659  0.105578  0.105578
# 3        0.099511 -0.027906 -0.027906
# 4       -0.014634  0.073959  0.073959

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
correlation = df_2.corr()["ret_exc_lead1m"].abs().sort_values(ascending = False)
corr_df = pd.DataFrame(correlation)
corr_df
# Out:
#                   ret_exc_lead1m
# ret_exc_lead1m          1.000000
# month                   0.073434
# std_turn                0.060731
# year                    0.053582
# turnover_126d           0.050795
# sic2                    0.046138
# ret_6_1                 0.039650
# ivol_capm_252d          0.033773
# bidaskhl_21d            0.033248
# id                      0.030248
# ret                     0.029874
# ret_exc                 0.029874
# ret_1_0                 0.029874
# betasq                  0.019315
# me                      0.015388
# ret_12_1                0.014049
# dolvol_126d             0.012489
# rvol_21d                0.008300
# chmom                   0.006504
# beta_60m                0.004135
# zero_trades_252d        0.002015
# rmax1_21d               0.001797

# %%
corr_df.to_excel(r'C:\Users\krist\Documents\Data\EDA\target_correlation.xlsx')
